# %% [markdown]
# <a href="https://colab.research.google.com/github/av1nash/machinelearning/blob/main/ML_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Course
# Machine learning foundation: https://www.youtube.com/watch?v=_Z9TRANg4c0

# %% [markdown]
# Relationship between X & Y ?

# %% [markdown]
# ![Screenshot 2021-05-23 222953.png](data:image/png;base64,...)

# %% [markdown]
# Y = 2X - 1

# %%
import keras
import numpy as np
model = keras.Sequential([keras.layers.Dense(units =1,input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1.0,0.0,1.0,2.0,3.0,4.0], dtype = float)
ys = np.array([-3.0,-1.0,1.0,3.0,5.0,7.0], dtype = float)

model.fit(xs,ys,epochs=500)
print(model.predict([10,0]))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 409ms/step - loss: 36.8002
# Epoch 2/500
# 1/1 [==============================] - 0s 4ms/step - loss: 29.2944
# Epoch 3/500
# 1/1 [==============================] - 0s 4ms/step - loss: 23.3823
# Epoch 4/500
# 1/1 [==============================] - 0s 9ms/step - loss: 18.7240
# Epoch 5/500
# 1/1 [==============================] - 0s 7ms/step - loss: 15.0523
# Epoch 6/500
# 1/1 [==============================] - 0s 5ms/step - loss: 12.1571
# Epoch 7/500
# 1/1 [==============================] - 0s 3ms/step - loss: 9.8727
# Epoch 8/500
# 1/1 [==============================] - 0s 5ms/step - loss: 8.0692
# Epoch 9/500
# 1/1 [==============================] - 0s 6ms/step - loss: 6.6441
# Epoch 10/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.5168
# Epoch 11/500
# 1/1 [==============================] - 0s 4ms/step - loss: 4.6239
# Epoch 12/500
# 1/1 [==============================] - 0s 4ms/step - loss: 3.9157
# ...
